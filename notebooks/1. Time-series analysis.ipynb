# %%
# %load_ext autoreload
# %autoreload 2
from pathlib import Path
from riap.api import load_config, Riap

# %% [markdown]
# ### 1. Initiate the analyzer

# %%
# 1. using a config gfile
cfg = load_config("IMPV2.yaml")
# riap_analyser = Riap(cfg)

# 2. overriding specific parameters
riap_analyser = Riap(
    cfg,
    data_path = "/media/elea/2TBBackUp/Nathan/2_FIXATION/data/Solution3/",
    path_output = "/media/elea/2TBBackUp/Nathan/2_FIXATION/results/Solution3/",
    alignment_method = "MatchAnything"
)
# Out:
# 2026-02-28 23:50:58.316 | INFO     | riap.api:__init__:86 - Data path set to: /media/elea/2TBBackUp/Nathan/2_FIXATION/data/Solution3
# 2026-02-28 23:50:58.317 | INFO     | riap.api:__init__:135 - Alignment method set to: MatchAnything
# 2026-02-28 23:50:58.318 | INFO     | riap.api:__init__:142 - Output path set to: /media/elea/2TBBackUp/Nathan/2_FIXATION/results/Solution3
# 2026-02-28 23:50:58.318 | INFO     | riap.api:__init__:164 - Force recompute set to: False
# 2026-02-28 23:50:58.319 | INFO     | riap.api:__init__:169 - Input parameters validated successfully
# 2026-02-28 23:50:58.319 | INFO     | riap.api:__init__:170 - Riap instance initiated successfully
#
# 2026-02-28 23:50:58.319 | INFO     | riap.api:__init__:175 - Alignment folders will be available in: /home/elea/Documents/HORAO/PROJECTS/5_RIAP/temp
# 2026-02-28 23:50:58.320 | INFO     | riap.api:__init__:178 - Base directories identified: ['/media/elea/2TBBackUp/Nathan/2_FIXATION/data/Solution3/2026-02-04_184514_F_OR_HORAO_6011_004', '/media/elea/2TBBackUp/Nathan/2_FIXATION/data/Solution3/2026-02-04_190614_F_OR_HORAO_6012_004', '/media/elea/2TBBackUp/Nathan/2_FIXATION/data/Solution3/2026-02-04_191044_F_OR_HORAO_6013_004', '/media/elea/2TBBackUp/Nathan/2_FIXATION/data/Solution3/2026-02-04_191351_F_OR_HORAO_6014_004', '/media/elea/2TBBackUp/Nathan/2_FIXATION/data/Solution3/2026-02-04_191737_F_OR_HORAO_6015_004']
# Creating masks for folders: 100%|███████████████| 35/35 [00:02<00:00, 15.59it/s]
# 2026-02-28 23:51:00.569 | INFO     | riap.api:__init__:181 - Tissue masks generated successfully
# 2026-02-28 23:51:00.569 | INFO     | riap.api:__init__:182 - Riap instance created successfully

# %% [markdown]
# ### 2. Perform the alignment (WARNING: THIS ERASES PREVIOUS COMPUTATIONS)

# %%
riap_analyser.align_and_propagate()
# Out:
# 2026-02-28 23:52:54.828 | INFO     | riap.riap:process:39 - Processing 2026-02-04_184514_F_OR_HORAO_6011_004: 1/5
#
# 2026-02-28 23:52:54.844 | INFO     | riap.riap:process:54 - Found 6 folders to propagate to: ['2026-02-04_125824_F_OR_HORAO_6011_001', '2026-02-04_150346_F_OR_HORAO_6011_002', '2026-02-05_133631_F_OR_HORAO_6011_005', '2026-02-06_130528_F_OR_HORAO_6011_006', '2026-02-11_132612_F_OR_HORAO_6011_007', '2026-02-18_163753_F_OR_HORAO_6011_008']
# 2026-02-28 23:52:54.844 | INFO     | riap.riap:process:56 - Step 1: Selecting ROIs
# 2026-02-28 23:52:55.353 | SUCCESS  | riap.riap:square_selection:137 - Selected 30 ROIs for WM.
# 2026-02-28 23:52:55.835 | SUCCESS  | riap.riap:square_selection:137 - Selected 30 ROIs for GM.
# 2026-02-28 23:52:55.835 | INFO     | riap.riap:process:68 - Step 2: Aligning images and propagating ROIs
# *****************cpu, True**************************
# 2026-02-28 23:52:59.538 | INFO     | MatchAnything.src.lightning.lightning_loftr:__init__:76 - Load model from:<All keys matched successfully>
# [2026/02/28 23:52:59 hloc INFO] Loading matchanything_roma model done
# [2026/02/28 23:52:59 hloc INFO] Matcher loaded from model/zoo
# [2026/02/28 23:52:59 hloc INFO] preprocessing is already resized
# [2026/02/28 23:53:39 hloc INFO] Matching images done using: 40.399s
# [2026/02/28 23:53:41 hloc INFO] ransac_method: CV2_RANSAC, geometry_type: Fundamental
# [2026/02/28 23:53:41 hloc INFO] ransac_method: CV2_RANSAC, geometry_type: Homography
# [2026/02/28 23:53:41 hloc INFO] RANSAC matches done using: 1.757s
# [2026/02/28 23:53:42 hloc INFO] Display matches done using: 1.132s
# [2026/02/28 23:53:43 hloc INFO] TOTAL time: 47.155s
# OpenJDK 64-Bit Server VM warning: ignoring option PermSize=128m; support was removed in 8.0
# OpenJDK 64-Bit Server VM warning: Using incremental CMS is deprecated and will likely be removed in a future release
# 2026-02-28 23:54:15.122 | INFO     | riap.riap:match_anything_alignment:261 - Matched points already exist for 2026-02-04_150346_F_OR_HORAO_6011_002. Skipping alignment.
# OpenJDK 64-Bit Server VM warning: ignoring option PermSize=128m; support was removed in 8.0
# OpenJDK 64-Bit Server VM warning: Using incremental CMS is deprecated and will likely be removed in a future release
# 2026-02-28 23:54:45.790 | INFO     | riap.riap:match_anything_alignment:261 - Matched points already exist for 2026-02-05_133631_F_OR_HORAO_6011_005. Skipping alignment.
# OpenJDK 64-Bit Server VM warning: ignoring option PermSize=128m; support was removed in 8.0
# OpenJDK 64-Bit Server VM warning: Using incremental CMS is deprecated and will likely be removed in a future release

# %% [markdown]
# ### 3. Generates the output for plotting

# %%
riap_analyser.compare_parameters()
