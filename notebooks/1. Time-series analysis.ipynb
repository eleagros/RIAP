# %%
# %load_ext autoreload
# %autoreload 2
from pathlib import Path
from riap.riap import load_config, Riap
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ### 1. Initiate the analyzer

# %%
# 1. using a config gfile
cfg = load_config("IMPV1.yaml")
# riap_analyser = Riap(cfg)

# 2. overriding specific parameters
riap_analyser = Riap(cfg, alignment_method = "superglue")
# Out:
# 2026-02-12 00:41:33.515 | INFO     | riap.riap:__init__:141 - Alignment method set to: superglue
# 2026-02-12 00:41:33.516 | INFO     | riap.riap:__init__:168 - Input parameters validated successfully
# 2026-02-12 00:41:33.517 | INFO     | riap.riap:__init__:169 - Riap instance initiated successfully
#
# 2026-02-12 00:41:33.518 | INFO     | riap.riap:__init__:174 - Alignment folders will be available in: /home/elea/Documents/HORAO/repositories/RIAP/temp
# 2026-02-12 00:41:33.518 | INFO     | riap.riap:__init__:177 - Base directories identified: ['/home/elea/Documents/HORAO/repositories/RIAP/data/impv2_dev/2025-08-05_132952_F_FF_HORAO_2003_003']
# Creating masks for folders: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 2/2 [00:00<00:00, 225.92it/s]
# 2026-02-12 00:41:33.529 | INFO     | riap.riap:__init__:180 - Tissue masks generated successfully
# 2026-02-12 00:41:33.529 | INFO     | riap.riap:__init__:181 - Riap instance created successfully

# %% [markdown]
# ### 2. Perform the alignment (WARNING: THIS ERASES PREVIOUS COMPUTATIONS)

# %%
riap_analyser.process()
# Out:
# 2026-02-12 00:41:35.081 | INFO     | riap.riap:process:225 - Processing 2025-08-05_132952_F_FF_HORAO_2003_003: 0/1
#
# 2026-02-12 00:41:35.103 | INFO     | riap.riap:process:241 - Found 1 folders to propagate to: ['2025-08-05_133033_F_FF_HORAO_2003_004']
# 2026-02-12 00:41:35.104 | INFO     | riap.riap:process:243 - Step 1: Selecting ROIs
# 2026-02-12 00:41:35.164 | SUCCESS  | riap.riap:__square_selection:309 - Selected 2 ROIs for WM.
# 2026-02-12 00:41:35.216 | SUCCESS  | riap.riap:__square_selection:309 - Selected 2 ROIs for GM.
# 2026-02-12 00:41:35.217 | INFO     | riap.riap:process:251 - Step 2: Aligning images and propagating ROIs
# Namespace(input='/home/elea/Documents/HORAO/repositories/RIAP/temp/alignment/to_align/2025-08-05_132952_F_FF_HORAO_2003_003__3beae29f-8c98-4a1b-99f7-6c6ff4d11338/2025-08-05_133033_F_FF_HORAO_2003_004', output_dir='/home/elea/Documents/HORAO/repositories/RIAP/temp/alignment/to_align/2025-08-05_132952_F_FF_HORAO_2003_003__3beae29f-8c98-4a1b-99f7-6c6ff4d11338/2025-08-05_133033_F_FF_HORAO_2003_004', image_glob=['*.png', '*.jpg', '*.jpeg'], skip=1, max_length=1000000, resize=[-1], superglue='outdoor', max_keypoints=-1, keypoint_threshold=0.005, nms_radius=4, sinkhorn_iterations=20, match_threshold=0.2, show_keypoints=False, no_display=True, force_cpu=False)
# Will not resize images
# Running inference on device "cuda"
# Loaded SuperPoint model
# Loaded SuperGlue model ("outdoor" weights)
# ==> Processing image directory input: /home/elea/Documents/HORAO/repositories/RIAP/temp/alignment/to_align/2025-08-05_132952_F_FF_HORAO_2003_003__3beae29f-8c98-4a1b-99f7-6c6ff4d11338/2025-08-05_133033_F_FF_HORAO_2003_004
# ==> Will write outputs to /home/elea/Documents/HORAO/repositories/RIAP/temp/alignment/to_align/2025-08-05_132952_F_FF_HORAO_2003_003__3beae29f-8c98-4a1b-99f7-6c6ff4d11338/2025-08-05_133033_F_FF_HORAO_2003_004
# Skipping visualization, will not show a GUI.
# ==> Keyboard control:
# 	n: select the current frame as the anchor
# 	e/r: increase/decrease the keypoint confidence threshold
# 	d/f: increase/decrease the match filtering threshold
# 	k: toggle the visualization of keypoints
# 	q: quit
# [Timer] data=0.005 forward=0.228 viz=0.009 total=0.242 sec {4.1 FPS}
# Writing image to /home/elea/Documents/HORAO/repositories/RIAP/temp/alignment/to_align/2025-08-05_132952_F_FF_HORAO_2003_003__3beae29f-8c98-4a1b-99f7-6c6ff4d11338/2025-08-05_133033_F_FF_HORAO_2003_004/matches_000000_000001.png
# Finished demo_superglue.py
# 2026-02-12 00:41:37.642 | INFO     | riap.riap:process:254 - Alignment completed
# 2026-02-12 00:41:37.643 | SUCCESS  | riap.riap:process:260 - Folders aligned successfully
# 2026-02-12 00:41:37.643 | INFO     | riap.riap:process:262 - Step 3: Propagating ROIs and collecting statistics
# Processing ROIs: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 4/4 [00:01<00:00,  2.17it/s]
# 2026-02-12 00:41:39.584 | SUCCESS  | riap.riap:process:264 - Results saved in /home/elea/Documents/HORAO/repositories/RIAP/data/impv2_dev/2025-08-05_132952_F_FF_HORAO_2003_003/RIAP_results

# %% [markdown]
# ### 3. Generates the output for plotting

# %%
riap_analyser.compare_parameters()
# Out:
# 2026-02-12 00:41:43.596 | INFO     | riap.riap:__export_results:548 - Exporting combined statistics to Excel files in /home/elea/Documents/HORAO/repositories/RIAP/output/IMPV2/superglue
