# %%
# %load_ext autoreload
# %autoreload 2
from pathlib import Path
import riap

# %% [markdown]
# ### 1. Initiate the analyzer

# %%
# 1. using a config gfile
cfg = riap.load_config("IMPV2.yaml")  # current options include "IMPV1.yaml" and "IMPV2.yaml"

# 2. overriding specific parameters
base_folder = Path("/home/elea/Documents/HORAO/PROJECTS/5_RIAP/data/IMPv2").resolve()
app = riap.Riap(
    cfg,
    data_path = base_folder / "measurements",
    path_output = base_folder / "results",
    alignment_method = "MatchAnything_opencv"
)
# current options for alignment_method include "MatchAnything_opencv", "MatchAnything_imageJ",
# "elastix" and "superglue"
# Out:
# 2026-03-12 00:51:58.659 | INFO     | riap.api:__init__:81 - Data path set to: /home/elea/Documents/HORAO/PROJECTS/5_RIAP/data/IMPv2/measurements
# 2026-03-12 00:51:58.660 | INFO     | riap.api:__init__:130 - Alignment method set to: MatchAnything_opencv
# 2026-03-12 00:51:58.660 | INFO     | riap.api:__init__:137 - Output path set to: /home/elea/Documents/HORAO/PROJECTS/5_RIAP/data/IMPv2/results
# 2026-03-12 00:51:58.661 | INFO     | riap.api:__init__:159 - Force recompute set to: False
# 2026-03-12 00:51:58.661 | INFO     | riap.api:__init__:164 - Input parameters validated successfully
# 2026-03-12 00:51:58.662 | INFO     | riap.api:__init__:165 - Riap instance initiated successfully
#
# 2026-03-12 00:51:58.663 | INFO     | riap.api:__init__:170 - Alignment folders will be available in: /home/elea/Documents/HORAO/PROJECTS/5_RIAP/temp
# 2026-03-12 00:51:58.664 | INFO     | riap.api:__init__:173 - Base directories identified: ['/home/elea/Documents/HORAO/PROJECTS/5_RIAP/data/IMPv2/measurements/2026-02-04_141906_F_OR_HORAO_6002_002']
# 2026-03-12 00:51:58.664 | INFO     | riap.api:__init__:180 - Riap instance created successfully

# %% [markdown]
# ### 2. Perform the alignment (WARNING: THIS ERASES PREVIOUS COMPUTATIONS)

# %%
app.align_and_propagate()
# Out:
# 2026-03-12 00:51:58.697 | INFO     | riap.riap:process:58 - Processing 2026-02-04_141906_F_OR_HORAO_6002_002: 1/1
#
# Creating masks for folders:   0%|                         | 0/3 [00:00<?, ?it/s][2026/03/12 00:52:01 hloc WARNING] pycolmap is not installed, some features may not work.
# Creating masks for folders:  33%|█████▋           | 1/3 [00:05<00:10,  5.26s/it]xFormers not available
# xFormers not available
# *****************cpu, True**************************
# 2026-03-12 00:52:08.901 | INFO     | MatchAnything.src.lightning.lightning_loftr:__init__:76 - Load model from:<All keys matched successfully>
# [2026/03/12 00:52:08 hloc INFO] Loading matchanything_roma model done
# [2026/03/12 00:52:08 hloc INFO] Matcher loaded from model/zoo
# [2026/03/12 00:52:08 hloc INFO] preprocessing is already resized
# [2026/03/12 00:52:58 hloc INFO] Matching images done using: 49.832s
# [2026/03/12 00:53:00 hloc INFO] ransac_method: CV2_RANSAC, geometry_type: Fundamental
# [2026/03/12 00:53:00 hloc INFO] ransac_method: CV2_RANSAC, geometry_type: Homography
# [2026/03/12 00:53:00 hloc INFO] RANSAC matches done using: 1.996s
# [2026/03/12 00:53:02 hloc INFO] Display matches done using: 1.538s
# [2026/03/12 00:53:02 hloc INFO] TOTAL time: 58.366s
# Creating masks for folders: 100%|█████████████████| 3/3 [01:07<00:00, 22.59s/it]
# 2026-03-12 00:53:06.591 | INFO     | riap.riap:process:84 - Found 3 folders to propagate to: ['2026-02-04_121213_F_OR_HORAO_6002_001', '2026-02-04_181925_F_OR_HORAO_6002_004', '2026-02-05_130512_F_OR_HORAO_6002_005']
# 2026-03-12 00:53:06.591 | INFO     | riap.riap:process:86 - Step 1: Selecting ROIs
# 2026-03-12 00:53:07.109 | SUCCESS  | riap.riap:square_selection:167 - Selected 30 ROIs for WM.
# 2026-03-12 00:53:07.597 | SUCCESS  | riap.riap:square_selection:167 - Selected 30 ROIs for GM.
# 2026-03-12 00:53:07.598 | INFO     | riap.riap:process:98 - Step 2: Aligning images and propagating ROIs
# 2026-03-12 00:53:07.616 | INFO     | riap.riap:match_anything_alignment:292 - Matched points already exist for 2026-02-04_121213_F_OR_HORAO_6002_001. Skipping alignment.
# *****************cpu, True**************************
# 2026-03-12 00:53:12.693 | INFO     | MatchAnything.src.lightning.lightning_loftr:__init__:76 - Load model from:<All keys matched successfully>
# [2026/03/12 00:53:12 hloc INFO] Loading matchanything_roma model done
# [2026/03/12 00:53:12 hloc INFO] Matcher loaded from model/zoo
# [2026/03/12 00:53:12 hloc INFO] preprocessing is already resized

# %% [markdown]
# ### 3. Generates the output for plotting and plot the results

# %%
app.compare_parameters()
app.plot_results()
