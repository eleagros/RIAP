# %%
# %load_ext autoreload
# %autoreload 2
from pathlib import Path
import riap
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ### 1. Initiate the analyzer

# %%
# 1. using a config gfile
cfg = riap.load_config("IMPv2.yaml")  # current options include "IMPV1.yaml" and "IMPV2.yaml"

# 2. overriding specific parameters
base_folder = Path("/home/elea/Documents/HORAO/DATABASES/7_FIXATION_METHODS/measurements")
app = riap.Riap(
    cfg,
    data_path = base_folder / "Solution2",
    calib_path = Path("/home/elea/Documents/HORAO/DATABASES/7_FIXATION_METHODS/calibration"),
    path_output = base_folder / "results" / "Solution2",
    alignment_method = "MatchAnything_opencv"
)
# current options for alignment_method include "MatchAnything_opencv", "MatchAnything_imageJ",
# "elastix" and "superglue"
# Out:
# 2026-03-19 20:48:29.267 | INFO     | riap.api:__init__:86 - Data path set to: /home/elea/Documents/HORAO/DATABASES/7_FIXATION_METHODS/measurements/Solution2
# 2026-03-19 20:48:29.268 | INFO     | riap.api:__init__:139 - Alignment method set to: MatchAnything_opencv
# 2026-03-19 20:48:29.269 | INFO     | riap.api:__init__:146 - Output path set to: /home/elea/Documents/HORAO/DATABASES/7_FIXATION_METHODS/measurements/results/Solution2
# 2026-03-19 20:48:29.270 | INFO     | riap.api:__init__:168 - Force recompute set to: False
# 2026-03-19 20:48:29.270 | INFO     | riap.api:__init__:173 - Input parameters validated successfully
# 2026-03-19 20:48:29.271 | INFO     | riap.api:__init__:174 - Riap instance initiated successfully
#
# 2026-03-19 20:48:29.272 | INFO     | riap.api:__init__:179 - Alignment folders will be available in: /home/elea/Documents/HORAO/PROJECTS/5_RIAP/temp
# 2026-03-19 20:48:29.273 | INFO     | riap.api:__init__:182 - Base directories identified: ['/home/elea/Documents/HORAO/DATABASES/7_FIXATION_METHODS/measurements/Solution2/2026-03-11_140107_F_OR_HORAO_6109_002', '/home/elea/Documents/HORAO/DATABASES/7_FIXATION_METHODS/measurements/Solution2/2026-03-11_140227_F_OR_HORAO_6110_002', '/home/elea/Documents/HORAO/DATABASES/7_FIXATION_METHODS/measurements/Solution2/2026-03-11_135909_F_OR_HORAO_6108_002', '/home/elea/Documents/HORAO/DATABASES/7_FIXATION_METHODS/measurements/Solution2/2026-03-11_135710_F_OR_HORAO_6107_002']
# 2026-03-19 20:48:29.274 | INFO     | riap.api:__init__:195 - Riap instance created successfully

# %% [markdown]
# ### 2. Perform the alignment (WARNING: THIS ERASES PREVIOUS COMPUTATIONS)

# %%
app.align_and_propagate()
# Out:
# 2026-03-19 19:59:51.324 | INFO     | riap.riap:process:58 - Processing 2026-03-11_142015_F_OR_HORAO_6115_002: 1/5
#
# Creating masks for folders: 100%|█████████████████| 4/4 [00:04<00:00,  1.06s/it]
# 2026-03-19 19:59:55.644 | INFO     | riap.riap:process:84 - Found 4 folders to propagate to: ['2026-03-11_120955_F_OR_HORAO_6115_001', '2026-03-11_181851_F_OR_HORAO_6115_003', '2026-03-12_134330_F_OR_HORAO_6115_004', '2026-03-13_155138_F_OR_HORAO_6115_005']
# 2026-03-19 19:59:55.645 | INFO     | riap.riap:process:86 - Step 1: Selecting ROIs
# 2026-03-19 19:59:56.329 | SUCCESS  | riap.riap:square_selection:167 - Selected 40 ROIs for WM.
# 2026-03-19 19:59:57.021 | SUCCESS  | riap.riap:square_selection:167 - Selected 40 ROIs for GM.
# 2026-03-19 19:59:57.021 | INFO     | riap.riap:process:98 - Step 2: Aligning images and propagating ROIs
# 2026-03-19 19:59:57.043 | INFO     | riap.riap:match_anything_alignment:292 - Matched points already exist for 2026-03-11_120955_F_OR_HORAO_6115_001. Skipping alignment.
# 2026-03-19 19:59:58.456 | INFO     | riap.riap:match_anything_alignment:292 - Matched points already exist for 2026-03-11_181851_F_OR_HORAO_6115_003. Skipping alignment.
# 2026-03-19 19:59:59.884 | INFO     | riap.riap:match_anything_alignment:292 - Matched points already exist for 2026-03-12_134330_F_OR_HORAO_6115_004. Skipping alignment.
# 2026-03-19 20:00:01.174 | INFO     | riap.riap:match_anything_alignment:292 - Matched points already exist for 2026-03-13_155138_F_OR_HORAO_6115_005. Skipping alignment.
# 2026-03-19 20:00:02.446 | INFO     | riap.riap:process:109 - Alignment completed
# 2026-03-19 20:00:02.447 | SUCCESS  | riap.riap:process:116 - Folders aligned successfully
# 2026-03-19 20:00:02.447 | INFO     | riap.riap:process:118 - Step 3: Propagating ROIs and collecting statistics
# Processing ROIs: 100%|██████████████████████████| 80/80 [01:46<00:00,  1.34s/it]
# 2026-03-19 20:01:50.370 | SUCCESS  | riap.riap:process:125 - Results saved in /home/elea/Documents/HORAO/DATABASES/7_FIXATION_METHODS/measurements/Solution3/2026-03-11_142015_F_OR_HORAO_6115_002/RIAP_results
#
# 2026-03-19 20:01:50.385 | INFO     | riap.riap:process:58 - Processing 2026-03-11_141813_F_OR_HORAO_6114_002: 2/5
#
# Creating masks for folders: 100%|█████████████████| 4/4 [00:04<00:00,  1.25s/it]
# 2026-03-19 20:01:55.467 | INFO     | riap.riap:process:84 - Found 4 folders to propagate to: ['2026-03-11_120646_F_OR_HORAO_6114_001', '2026-03-11_181714_F_OR_HORAO_6114_003', '2026-03-12_134234_F_OR_HORAO_6114_004', '2026-03-13_155021_F_OR_HORAO_6114_005']
# 2026-03-19 20:01:55.468 | INFO     | riap.riap:process:86 - Step 1: Selecting ROIs
# 2026-03-19 20:01:56.202 | SUCCESS  | riap.riap:square_selection:167 - Selected 40 ROIs for WM.
# 2026-03-19 20:01:56.845 | SUCCESS  | riap.riap:square_selection:167 - Selected 40 ROIs for GM.
# 2026-03-19 20:01:56.846 | INFO     | riap.riap:process:98 - Step 2: Aligning images and propagating ROIs
# 2026-03-19 20:01:56.866 | INFO     | riap.riap:match_anything_alignment:292 - Matched points already exist for 2026-03-11_120646_F_OR_HORAO_6114_001. Skipping alignment.
# 2026-03-19 20:01:58.339 | INFO     | riap.riap:match_anything_alignment:292 - Matched points already exist for 2026-03-11_181714_F_OR_HORAO_6114_003. Skipping alignment.
# 2026-03-19 20:01:59.720 | INFO     | riap.riap:match_anything_alignment:292 - Matched points already exist for 2026-03-12_134234_F_OR_HORAO_6114_004. Skipping alignment.
# 2026-03-19 20:02:01.015 | INFO     | riap.riap:match_anything_alignment:292 - Matched points already exist for 2026-03-13_155021_F_OR_HORAO_6114_005. Skipping alignment.
# 2026-03-19 20:02:02.439 | INFO     | riap.riap:process:109 - Alignment completed
# 2026-03-19 20:02:02.440 | SUCCESS  | riap.riap:process:116 - Folders aligned successfully
# 2026-03-19 20:02:02.440 | INFO     | riap.riap:process:118 - Step 3: Propagating ROIs and collecting statistics
# Processing ROIs: 100%|██████████████████████████| 80/80 [01:45<00:00,  1.32s/it]
# 2026-03-19 20:03:49.191 | SUCCESS  | riap.riap:process:125 - Results saved in /home/elea/Documents/HORAO/DATABASES/7_FIXATION_METHODS/measurements/Solution3/2026-03-11_141813_F_OR_HORAO_6114_002/RIAP_results
#
# 2026-03-19 20:03:49.223 | INFO     | riap.riap:process:58 - Processing 2026-03-11_141408_F_OR_HORAO_6112_002: 3/5
#
# Creating masks for folders: 100%|█████████████████| 4/4 [00:04<00:00,  1.07s/it]
# 2026-03-19 20:03:53.579 | INFO     | riap.riap:process:84 - Found 4 folders to propagate to: ['2026-03-11_120250_F_OR_HORAO_6112_001', '2026-03-11_181420_F_OR_HORAO_6112_003', '2026-03-12_133950_F_OR_HORAO_6112_004', '2026-03-13_154736_F_OR_HORAO_6112_005']
# 2026-03-19 20:03:53.579 | INFO     | riap.riap:process:86 - Step 1: Selecting ROIs
# 2026-03-19 20:03:54.249 | SUCCESS  | riap.riap:square_selection:167 - Selected 40 ROIs for WM.
# 2026-03-19 20:03:54.939 | SUCCESS  | riap.riap:square_selection:167 - Selected 40 ROIs for GM.
# 2026-03-19 20:03:54.940 | INFO     | riap.riap:process:98 - Step 2: Aligning images and propagating ROIs
# 2026-03-19 20:03:54.966 | INFO     | riap.riap:match_anything_alignment:292 - Matched points already exist for 2026-03-11_120250_F_OR_HORAO_6112_001. Skipping alignment.
# 2026-03-19 20:03:56.349 | INFO     | riap.riap:match_anything_alignment:292 - Matched points already exist for 2026-03-11_181420_F_OR_HORAO_6112_003. Skipping alignment.
# 2026-03-19 20:03:57.692 | INFO     | riap.riap:match_anything_alignment:292 - Matched points already exist for 2026-03-12_133950_F_OR_HORAO_6112_004. Skipping alignment.
# 2026-03-19 20:03:58.973 | INFO     | riap.riap:match_anything_alignment:292 - Matched points already exist for 2026-03-13_154736_F_OR_HORAO_6112_005. Skipping alignment.
# 2026-03-19 20:04:00.220 | INFO     | riap.riap:process:109 - Alignment completed
# 2026-03-19 20:04:00.221 | SUCCESS  | riap.riap:process:116 - Folders aligned successfully
# 2026-03-19 20:04:00.222 | INFO     | riap.riap:process:118 - Step 3: Propagating ROIs and collecting statistics
# Processing ROIs: 100%|██████████████████████████| 80/80 [01:50<00:00,  1.38s/it]
# 2026-03-19 20:05:52.128 | SUCCESS  | riap.riap:process:125 - Results saved in /home/elea/Documents/HORAO/DATABASES/7_FIXATION_METHODS/measurements/Solution3/2026-03-11_141408_F_OR_HORAO_6112_002/RIAP_results
#
# 2026-03-19 20:05:52.142 | INFO     | riap.riap:process:58 - Processing 2026-03-11_141159_F_OR_HORAO_6111_002: 4/5
#
# Creating masks for folders: 100%|█████████████████| 4/4 [00:04<00:00,  1.16s/it]
# 2026-03-19 20:05:56.871 | INFO     | riap.riap:process:84 - Found 4 folders to propagate to: ['2026-03-11_120115_F_OR_HORAO_6111_001', '2026-03-11_181250_F_OR_HORAO_6111_003', '2026-03-12_133814_F_OR_HORAO_6111_004', '2026-03-13_154605_F_OR_HORAO_6111_005']
# 2026-03-19 20:05:56.871 | INFO     | riap.riap:process:86 - Step 1: Selecting ROIs
# 2026-03-19 20:05:57.655 | SUCCESS  | riap.riap:square_selection:167 - Selected 40 ROIs for WM.
# 2026-03-19 20:05:58.350 | SUCCESS  | riap.riap:square_selection:167 - Selected 40 ROIs for GM.
# 2026-03-19 20:05:58.351 | INFO     | riap.riap:process:98 - Step 2: Aligning images and propagating ROIs
# 2026-03-19 20:05:58.374 | INFO     | riap.riap:match_anything_alignment:292 - Matched points already exist for 2026-03-11_120115_F_OR_HORAO_6111_001. Skipping alignment.
# 2026-03-19 20:05:59.847 | INFO     | riap.riap:match_anything_alignment:292 - Matched points already exist for 2026-03-11_181250_F_OR_HORAO_6111_003. Skipping alignment.
# 2026-03-19 20:06:01.354 | INFO     | riap.riap:match_anything_alignment:292 - Matched points already exist for 2026-03-12_133814_F_OR_HORAO_6111_004. Skipping alignment.
# 2026-03-19 20:06:02.836 | INFO     | riap.riap:match_anything_alignment:292 - Matched points already exist for 2026-03-13_154605_F_OR_HORAO_6111_005. Skipping alignment.
# 2026-03-19 20:06:04.259 | INFO     | riap.riap:process:109 - Alignment completed
# 2026-03-19 20:06:04.260 | SUCCESS  | riap.riap:process:116 - Folders aligned successfully
# 2026-03-19 20:06:04.261 | INFO     | riap.riap:process:118 - Step 3: Propagating ROIs and collecting statistics
# Processing ROIs: 100%|██████████████████████████| 80/80 [02:01<00:00,  1.51s/it]
# 2026-03-19 20:08:06.717 | SUCCESS  | riap.riap:process:125 - Results saved in /home/elea/Documents/HORAO/DATABASES/7_FIXATION_METHODS/measurements/Solution3/2026-03-11_141159_F_OR_HORAO_6111_002/RIAP_results
#
# 2026-03-19 20:08:06.732 | INFO     | riap.riap:process:58 - Processing 2026-03-11_141649_F_OR_HORAO_6113_002: 5/5
#
# Creating masks for folders: 100%|█████████████████| 4/4 [00:05<00:00,  1.46s/it]
# 2026-03-19 20:08:12.735 | INFO     | riap.riap:process:84 - Found 4 folders to propagate to: ['2026-03-11_120431_F_OR_HORAO_6113_001', '2026-03-11_181535_F_OR_HORAO_6113_003', '2026-03-12_134107_F_OR_HORAO_6113_004', '2026-03-13_154901_F_OR_HORAO_6113_005']
# 2026-03-19 20:08:12.736 | INFO     | riap.riap:process:86 - Step 1: Selecting ROIs
# 2026-03-19 20:08:13.415 | SUCCESS  | riap.riap:square_selection:167 - Selected 40 ROIs for WM.
# 2026-03-19 20:08:14.160 | SUCCESS  | riap.riap:square_selection:167 - Selected 40 ROIs for GM.
# 2026-03-19 20:08:14.161 | INFO     | riap.riap:process:98 - Step 2: Aligning images and propagating ROIs
# 2026-03-19 20:08:14.182 | INFO     | riap.riap:match_anything_alignment:292 - Matched points already exist for 2026-03-11_120431_F_OR_HORAO_6113_001. Skipping alignment.
# 2026-03-19 20:08:15.724 | INFO     | riap.riap:match_anything_alignment:292 - Matched points already exist for 2026-03-11_181535_F_OR_HORAO_6113_003. Skipping alignment.
# 2026-03-19 20:08:17.438 | INFO     | riap.riap:match_anything_alignment:292 - Matched points already exist for 2026-03-12_134107_F_OR_HORAO_6113_004. Skipping alignment.
# 2026-03-19 20:08:18.966 | INFO     | riap.riap:match_anything_alignment:292 - Matched points already exist for 2026-03-13_154901_F_OR_HORAO_6113_005. Skipping alignment.
# 2026-03-19 20:08:20.598 | INFO     | riap.riap:process:109 - Alignment completed
# 2026-03-19 20:08:20.599 | SUCCESS  | riap.riap:process:116 - Folders aligned successfully
# 2026-03-19 20:08:20.599 | INFO     | riap.riap:process:118 - Step 3: Propagating ROIs and collecting statistics
# Processing ROIs: 100%|██████████████████████████| 80/80 [02:16<00:00,  1.71s/it]
# 2026-03-19 20:10:39.070 | SUCCESS  | riap.riap:process:125 - Results saved in /home/elea/Documents/HORAO/DATABASES/7_FIXATION_METHODS/measurements/Solution3/2026-03-11_141649_F_OR_HORAO_6113_002/RIAP_results

# %% [markdown]
# ### 3. Generates the output for plotting and plot the results

# %%
app.compare_parameters()
# Out:
# 2026-03-19 20:48:33.916 | INFO     | riap.compare_parameters:export_results:108 - Exporting combined statistics to Excel files in /home/elea/Documents/HORAO/DATABASES/7_FIXATION_METHODS/measurements/results/Solution2/MatchAnything_opencv
# 2026-03-19 20:48:34.879 | SUCCESS  | riap.compare_parameters:run_compare_pipeline:24 - Comparison of parameters completed and results exported to /home/elea/Documents/HORAO/DATABASES/7_FIXATION_METHODS/measurements/results/Solution2/MatchAnything_opencv

# %%
app.plot_results()
# Out:
# /home/elea/Documents/HORAO/DATABASES/7_FIXATION_METHODS/measurements/results/Solution2/MatchAnything_opencv/plots/Azimuth local variability_cv.png
# /home/elea/Documents/HORAO/DATABASES/7_FIXATION_METHODS/measurements/results/Solution2/MatchAnything_opencv/plots/Azimuth local variability.png
# /home/elea/Documents/HORAO/DATABASES/7_FIXATION_METHODS/measurements/results/Solution2/MatchAnything_opencv/plots/Total diattenuation_cv.png
# /home/elea/Documents/HORAO/DATABASES/7_FIXATION_METHODS/measurements/results/Solution2/MatchAnything_opencv/plots/Azimuth of the optical axis_cv.png
# /home/elea/Documents/HORAO/DATABASES/7_FIXATION_METHODS/measurements/results/Solution2/MatchAnything_opencv/plots/Linear retardance.png
# /home/elea/Documents/HORAO/DATABASES/7_FIXATION_METHODS/measurements/results/Solution2/MatchAnything_opencv/plots/Azimuth of the optical axis.png
# /home/elea/Documents/HORAO/DATABASES/7_FIXATION_METHODS/measurements/results/Solution2/MatchAnything_opencv/plots/Total diattenuation.png
# /home/elea/Documents/HORAO/DATABASES/7_FIXATION_METHODS/measurements/results/Solution2/MatchAnything_opencv/plots/Total depolarization_cv.png
# /home/elea/Documents/HORAO/DATABASES/7_FIXATION_METHODS/measurements/results/Solution2/MatchAnything_opencv/plots/Total depolarization.png
# /home/elea/Documents/HORAO/DATABASES/7_FIXATION_METHODS/measurements/results/Solution2/MatchAnything_opencv/plots/Linear retardance_cv.png
