# %%
# %load_ext autoreload
# %autoreload 2
from pathlib import Path
from riap.api import load_config, Riap
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ### 1. Initiate the analyzer

# %%
# 1. using a config gfile
cfg = load_config("IMPV1.yaml")
# riap_analyser = Riap(cfg)

# 2. overriding specific parameters
riap_analyser = Riap(
    cfg,
    data_path = "/home/elea/Documents/HORAO/PROJECTS/5_RIAP/data/measurements/",
    path_output = "/home/elea/Documents/HORAO/PROJECTS/5_RIAP/data/results/",
    alignment_method = "MatchAnything"
)
# Out:
# 2026-03-01 00:05:24.165 | INFO     | riap.api:__init__:79 - Data path set to: /home/elea/Documents/HORAO/PROJECTS/5_RIAP/data/measurements
# 2026-03-01 00:05:24.166 | INFO     | riap.api:__init__:128 - Alignment method set to: MatchAnything
# 2026-03-01 00:05:24.167 | INFO     | riap.api:__init__:135 - Output path set to: /home/elea/Documents/HORAO/PROJECTS/5_RIAP/data/results
# 2026-03-01 00:05:24.167 | INFO     | riap.api:__init__:157 - Force recompute set to: False
# 2026-03-01 00:05:24.168 | INFO     | riap.api:__init__:162 - Input parameters validated successfully
# 2026-03-01 00:05:24.168 | INFO     | riap.api:__init__:163 - Riap instance initiated successfully
#
# 2026-03-01 00:05:24.169 | INFO     | riap.api:__init__:168 - Alignment folders will be available in: /home/elea/Documents/HORAO/PROJECTS/5_RIAP/temp
# 2026-03-01 00:05:24.169 | INFO     | riap.api:__init__:171 - Base directories identified: ['/home/elea/Documents/HORAO/PROJECTS/5_RIAP/data/measurements/2025-06-05_T_CALF_FR_T0_S5_1']
# Creating masks for folders: 100%|█████████████████| 6/6 [00:00<00:00, 24.68it/s]
# 2026-03-01 00:05:24.414 | INFO     | riap.api:__init__:174 - Tissue masks generated successfully
# 2026-03-01 00:05:24.414 | INFO     | riap.api:__init__:175 - Riap instance created successfully

# %% [markdown]
# ### 2. Perform the alignment (WARNING: THIS ERASES PREVIOUS COMPUTATIONS)

# %%
riap_analyser.align_and_propagate()
# Out:
# 2026-03-01 00:05:24.816 | INFO     | riap.riap:process:39 - Processing 2025-06-05_T_CALF_FR_T0_S5_1: 1/1
#
# 2026-03-01 00:05:24.908 | INFO     | riap.riap:process:54 - Found 5 folders to propagate to: ['2025-06-05_T_CALF_FR_T3_S5_1', '2025-06-05_T_CALF_FR_T1_S5_1', '2025-06-05_T_CALF_FR_T2_S5_1', '2025-06-05_T_CALF_FR_T5_S5_1', '2025-06-05_T_CALF_FR_T4_S5_1']
# 2026-03-01 00:05:24.909 | INFO     | riap.riap:process:56 - Step 1: Selecting ROIs
# 2026-03-01 00:05:25.223 | SUCCESS  | riap.riap:square_selection:137 - Selected 30 ROIs for WM.
# 2026-03-01 00:05:25.551 | SUCCESS  | riap.riap:square_selection:137 - Selected 30 ROIs for GM.
# 2026-03-01 00:05:25.552 | INFO     | riap.riap:process:68 - Step 2: Aligning images and propagating ROIs
# 2026-03-01 00:05:25.568 | INFO     | riap.riap:match_anything_alignment:261 - Matched points already exist for 2025-06-05_T_CALF_FR_T3_S5_1. Skipping alignment.
# OpenJDK 64-Bit Server VM warning: ignoring option PermSize=128m; support was removed in 8.0
# OpenJDK 64-Bit Server VM warning: Using incremental CMS is deprecated and will likely be removed in a future release
# [ERROR] java.rmi.ConnectException: Connection refused to host: 127.0.1.1; nested exception is:
# 	java.net.ConnectException: Connection refused (Connection refused)
# 	at sun.rmi.transport.tcp.TCPEndpoint.newSocket(TCPEndpoint.java:623)
# 	at sun.rmi.transport.tcp.TCPChannel.createConnection(TCPChannel.java:216)
# 	at sun.rmi.transport.tcp.TCPChannel.newConnection(TCPChannel.java:202)
# 	at sun.rmi.server.UnicastRef.invoke(UnicastRef.java:132)
# 	at java.rmi.server.RemoteObjectInvocationHandler.invokeRemoteMethod(RemoteObjectInvocationHandler.java:235)
# 	at java.rmi.server.RemoteObjectInvocationHandler.invoke(RemoteObjectInvocationHandler.java:180)
# 	at net.imagej.legacy.$Proxy10.sendArgument(Unknown Source)
# 	at net.imagej.legacy.SingleInstance.sendArguments(SingleInstance.java:198)
# 	at net.imagej.legacy.SingleInstance.sendArguments(SingleInstance.java:163)
# 	at net.imagej.legacy.SingleInstanceArgument.supports(SingleInstanceArgument.java:208)
# 	at net.imagej.legacy.SingleInstanceArgument.supports(SingleInstanceArgument.java:99)
# 	at org.scijava.plugin.HandlerService.getHandler(HandlerService.java:58)
# 	at org.scijava.console.DefaultConsoleService.processArgs(DefaultConsoleService.java:86)
# 	at org.scijava.AbstractGateway.launch(AbstractGateway.java:104)
# 	at net.imagej.Main.main(Main.java:53)
# 	at sun.reflect.NativeMethodAccessorImpl.invoke0(Native Method)
# 	at sun.reflect.NativeMethodAccessorImpl.invoke(NativeMethodAccessorImpl.java:62)
# 	at sun.reflect.DelegatingMethodAccessorImpl.invoke(DelegatingMethodAccessorImpl.java:43)
# 	at java.lang.reflect.Method.invoke(Method.java:498)
# 	at net.imagej.launcher.ClassLauncher.launch(ClassLauncher.java:279)
# 	at net.imagej.launcher.ClassLauncher.run(ClassLauncher.java:186)
# 	at net.imagej.launcher.ClassLauncher.main(ClassLauncher.java:87)
# Caused by: java.net.ConnectException: Connection refused (Connection refused)
# 	at java.net.PlainSocketImpl.socketConnect(Native Method)
# 	at java.net.AbstractPlainSocketImpl.doConnect(AbstractPlainSocketImpl.java:350)
# 	at java.net.AbstractPlainSocketImpl.connectToAddress(AbstractPlainSocketImpl.java:206)
# 	at java.net.AbstractPlainSocketImpl.connect(AbstractPlainSocketImpl.java:188)
# 	at java.net.SocksSocketImpl.connect(SocksSocketImpl.java:392)
# 	at java.net.Socket.connect(Socket.java:613)
# 	at java.net.Socket.connect(Socket.java:561)
# 	at java.net.Socket.<init>(Socket.java:457)
# 	at java.net.Socket.<init>(Socket.java:234)
# 	at sun.rmi.transport.proxy.RMIDirectSocketFactory.createSocket(RMIDirectSocketFactory.java:40)
# 	at sun.rmi.transport.proxy.RMIMasterSocketFactory.createSocket(RMIMasterSocketFactory.java:148)
# 	at sun.rmi.transport.tcp.TCPEndpoint.newSocket(TCPEndpoint.java:617)
# 	... 21 more
# [ERROR] Could not connect to existing ImageJ instance. If problem persists, please delete file: /tmp/ImageJ-elea-_99-7.stub
# *****************cpu, True**************************
# 2026-03-01 00:05:52.052 | INFO     | MatchAnything.src.lightning.lightning_loftr:__init__:76 - Load model from:<All keys matched successfully>
# [2026/03/01 00:05:52 hloc INFO] Loading matchanything_roma model done
# [2026/03/01 00:05:52 hloc INFO] Matcher loaded from model/zoo
# [2026/03/01 00:05:52 hloc INFO] preprocessing is already resized
# [2026/03/01 00:06:36 hloc INFO] Matching images done using: 44.141s
# [2026/03/01 00:06:37 hloc INFO] ransac_method: CV2_RANSAC, geometry_type: Fundamental
# [2026/03/01 00:06:37 hloc INFO] ransac_method: CV2_RANSAC, geometry_type: Homography
# [2026/03/01 00:06:37 hloc INFO] RANSAC matches done using: 1.774s
# [2026/03/01 00:06:39 hloc INFO] Display matches done using: 1.284s
# [2026/03/01 00:06:39 hloc INFO] TOTAL time: 51.018s
# OpenJDK 64-Bit Server VM warning: ignoring option PermSize=128m; support was removed in 8.0
# OpenJDK 64-Bit Server VM warning: Using incremental CMS is deprecated and will likely be removed in a future release
# *****************cpu, True**************************
# 2026-03-01 00:07:09.079 | INFO     | MatchAnything.src.lightning.lightning_loftr:__init__:76 - Load model from:<All keys matched successfully>
# [2026/03/01 00:07:09 hloc INFO] Loading matchanything_roma model done
# [2026/03/01 00:07:09 hloc INFO] Matcher loaded from model/zoo
# [2026/03/01 00:07:09 hloc INFO] preprocessing is already resized
# [2026/03/01 00:07:54 hloc INFO] Matching images done using: 44.959s
# [2026/03/01 00:07:56 hloc INFO] ransac_method: CV2_RANSAC, geometry_type: Fundamental
# [2026/03/01 00:07:56 hloc INFO] ransac_method: CV2_RANSAC, geometry_type: Homography
# [2026/03/01 00:07:56 hloc INFO] RANSAC matches done using: 1.994s
# [2026/03/01 00:07:57 hloc INFO] Display matches done using: 1.398s
# [2026/03/01 00:07:57 hloc INFO] TOTAL time: 52.623s
# OpenJDK 64-Bit Server VM warning: ignoring option PermSize=128m; support was removed in 8.0
# OpenJDK 64-Bit Server VM warning: Using incremental CMS is deprecated and will likely be removed in a future release
# *****************cpu, True**************************
# 2026-03-01 00:08:29.218 | INFO     | MatchAnything.src.lightning.lightning_loftr:__init__:76 - Load model from:<All keys matched successfully>
# [2026/03/01 00:08:29 hloc INFO] Loading matchanything_roma model done
# [2026/03/01 00:08:29 hloc INFO] Matcher loaded from model/zoo
# [2026/03/01 00:08:29 hloc INFO] preprocessing is already resized
# [2026/03/01 00:09:13 hloc INFO] Matching images done using: 43.847s
# [2026/03/01 00:09:15 hloc INFO] ransac_method: CV2_RANSAC, geometry_type: Fundamental
# [2026/03/01 00:09:15 hloc INFO] ransac_method: CV2_RANSAC, geometry_type: Homography
# [2026/03/01 00:09:15 hloc INFO] RANSAC matches done using: 2.220s
# [2026/03/01 00:09:16 hloc INFO] Display matches done using: 1.240s
# [2026/03/01 00:09:16 hloc INFO] TOTAL time: 51.665s
# OpenJDK 64-Bit Server VM warning: ignoring option PermSize=128m; support was removed in 8.0
# OpenJDK 64-Bit Server VM warning: Using incremental CMS is deprecated and will likely be removed in a future release
# *****************cpu, True**************************
# 2026-03-01 00:09:44.262 | INFO     | MatchAnything.src.lightning.lightning_loftr:__init__:76 - Load model from:<All keys matched successfully>
# [2026/03/01 00:09:44 hloc INFO] Loading matchanything_roma model done
# [2026/03/01 00:09:44 hloc INFO] Matcher loaded from model/zoo
# [2026/03/01 00:09:44 hloc INFO] preprocessing is already resized
# [2026/03/01 00:10:31 hloc INFO] Matching images done using: 47.161s
# [2026/03/01 00:10:33 hloc INFO] ransac_method: CV2_RANSAC, geometry_type: Fundamental
# [2026/03/01 00:10:33 hloc INFO] ransac_method: CV2_RANSAC, geometry_type: Homography
# [2026/03/01 00:10:33 hloc INFO] RANSAC matches done using: 2.367s
# [2026/03/01 00:10:35 hloc INFO] Display matches done using: 1.461s
# [2026/03/01 00:10:35 hloc INFO] TOTAL time: 55.226s
# OpenJDK 64-Bit Server VM warning: ignoring option PermSize=128m; support was removed in 8.0
# OpenJDK 64-Bit Server VM warning: Using incremental CMS is deprecated and will likely be removed in a future release
# 2026-03-01 00:10:59.743 | INFO     | riap.riap:process:79 - Alignment completed
# 2026-03-01 00:10:59.744 | SUCCESS  | riap.riap:process:86 - Folders aligned successfully
# 2026-03-01 00:10:59.744 | INFO     | riap.riap:process:88 - Step 3: Propagating ROIs and collecting statistics
# Processing ROIs: 100%|██████████████████████████| 60/60 [01:55<00:00,  1.92s/it]
# 2026-03-01 00:12:56.628 | SUCCESS  | riap.riap:process:95 - Results saved in /home/elea/Documents/HORAO/PROJECTS/5_RIAP/data/measurements/2025-06-05_T_CALF_FR_T0_S5_1/polarimetry/550nm/50x50_images

# %% [markdown]
# ### 3. Generates the output for plotting

# %%
riap_analyser.compare_parameters()
# Out:
# 2026-03-01 00:19:53.005 | INFO     | riap.compare_parameters:export_results:101 - Exporting combined statistics to Excel files in /home/elea/Documents/HORAO/PROJECTS/5_RIAP/data/results
# 2026-03-01 00:19:53.134 | SUCCESS  | riap.compare_parameters:run_compare_pipeline:22 - Comparison of parameters completed and results exported to /home/elea/Documents/HORAO/PROJECTS/5_RIAP/data/results
