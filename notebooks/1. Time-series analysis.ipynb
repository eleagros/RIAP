# %%
# %load_ext autoreload
# %autoreload 2
from pathlib import Path
from riap.riap import load_config, Riap

# %% [markdown]
# ### 1. Initiate the analyzer

# %%
# 1. using a config gfile
cfg = load_config("IMPV1.yaml")
# riap_analyser = Riap(cfg)

# 2. overriding specific parameters
riap_analyser = Riap(cfg, alignment_method = "superglue")
# Out:
# 2026-02-12 00:46:12.994 | INFO     | riap.riap:__init__:141 - Alignment method set to: superglue
# 2026-02-12 00:46:12.995 | INFO     | riap.riap:__init__:168 - Input parameters validated successfully
# 2026-02-12 00:46:12.995 | INFO     | riap.riap:__init__:169 - Riap instance initiated successfully
#
# 2026-02-12 00:46:12.995 | INFO     | riap.riap:__init__:174 - Alignment folders will be available in: /home/elea/Documents/HORAO/repositories/RIAP/temp
# 2026-02-12 00:46:12.996 | INFO     | riap.riap:__init__:177 - Base directories identified: ['/home/elea/Documents/HORAO/repositories/RIAP/data/measurements/2025-06-05_T_CALF_FR_T0_S5_1']
# Creating masks for folders: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 6/6 [00:00<00:00, 134.13it/s]
# 2026-02-12 00:46:13.045 | INFO     | riap.riap:__init__:180 - Tissue masks generated successfully
# 2026-02-12 00:46:13.045 | INFO     | riap.riap:__init__:181 - Riap instance created successfully

# %% [markdown]
# ### 2. Perform the alignment (WARNING: THIS ERASES PREVIOUS COMPUTATIONS)

# %%
riap_analyser.process()
# Out:
# 2026-02-12 00:46:13.063 | INFO     | riap.riap:process:225 - Processing 2025-06-05_T_CALF_FR_T0_S5_1: 0/1
#
# 2026-02-12 00:46:13.148 | INFO     | riap.riap:process:241 - Found 5 folders to propagate to: ['2025-06-05_T_CALF_FR_T3_S5_1', '2025-06-05_T_CALF_FR_T1_S5_1', '2025-06-05_T_CALF_FR_T2_S5_1', '2025-06-05_T_CALF_FR_T5_S5_1', '2025-06-05_T_CALF_FR_T4_S5_1']
# 2026-02-12 00:46:13.149 | INFO     | riap.riap:process:243 - Step 1: Selecting ROIs
# 2026-02-12 00:46:13.188 | SUCCESS  | riap.riap:__square_selection:309 - Selected 2 ROIs for WM.
# 2026-02-12 00:46:13.229 | SUCCESS  | riap.riap:__square_selection:309 - Selected 2 ROIs for GM.
# 2026-02-12 00:46:13.230 | INFO     | riap.riap:process:251 - Step 2: Aligning images and propagating ROIs
# Namespace(input='/home/elea/Documents/HORAO/repositories/RIAP/temp/alignment/to_align/2025-06-05_T_CALF_FR_T0_S5_1__3c02f1ad-4c54-4ab7-ba40-b9a38aeea1f9/2025-06-05_T_CALF_FR_T3_S5_1', output_dir='/home/elea/Documents/HORAO/repositories/RIAP/temp/alignment/to_align/2025-06-05_T_CALF_FR_T0_S5_1__3c02f1ad-4c54-4ab7-ba40-b9a38aeea1f9/2025-06-05_T_CALF_FR_T3_S5_1', image_glob=['*.png', '*.jpg', '*.jpeg'], skip=1, max_length=1000000, resize=[-1], superglue='outdoor', max_keypoints=-1, keypoint_threshold=0.005, nms_radius=4, sinkhorn_iterations=20, match_threshold=0.2, show_keypoints=False, no_display=True, force_cpu=False)
# Will not resize images
# Running inference on device "cuda"
# Loaded SuperPoint model
# Loaded SuperGlue model ("outdoor" weights)
# ==> Processing image directory input: /home/elea/Documents/HORAO/repositories/RIAP/temp/alignment/to_align/2025-06-05_T_CALF_FR_T0_S5_1__3c02f1ad-4c54-4ab7-ba40-b9a38aeea1f9/2025-06-05_T_CALF_FR_T3_S5_1
# ==> Will write outputs to /home/elea/Documents/HORAO/repositories/RIAP/temp/alignment/to_align/2025-06-05_T_CALF_FR_T0_S5_1__3c02f1ad-4c54-4ab7-ba40-b9a38aeea1f9/2025-06-05_T_CALF_FR_T3_S5_1
# Skipping visualization, will not show a GUI.
# ==> Keyboard control:
# 	n: select the current frame as the anchor
# 	e/r: increase/decrease the keypoint confidence threshold
# 	d/f: increase/decrease the match filtering threshold
# 	k: toggle the visualization of keypoints
# 	q: quit
# [Timer] data=0.003 forward=0.128 viz=0.004 total=0.134 sec {7.5 FPS}
# Writing image to /home/elea/Documents/HORAO/repositories/RIAP/temp/alignment/to_align/2025-06-05_T_CALF_FR_T0_S5_1__3c02f1ad-4c54-4ab7-ba40-b9a38aeea1f9/2025-06-05_T_CALF_FR_T3_S5_1/matches_000000_000001.png
# Finished demo_superglue.py
# Namespace(input='/home/elea/Documents/HORAO/repositories/RIAP/temp/alignment/to_align/2025-06-05_T_CALF_FR_T0_S5_1__3c02f1ad-4c54-4ab7-ba40-b9a38aeea1f9/2025-06-05_T_CALF_FR_T1_S5_1', output_dir='/home/elea/Documents/HORAO/repositories/RIAP/temp/alignment/to_align/2025-06-05_T_CALF_FR_T0_S5_1__3c02f1ad-4c54-4ab7-ba40-b9a38aeea1f9/2025-06-05_T_CALF_FR_T1_S5_1', image_glob=['*.png', '*.jpg', '*.jpeg'], skip=1, max_length=1000000, resize=[-1], superglue='outdoor', max_keypoints=-1, keypoint_threshold=0.005, nms_radius=4, sinkhorn_iterations=20, match_threshold=0.2, show_keypoints=False, no_display=True, force_cpu=False)
# Will not resize images
# Running inference on device "cuda"
# Loaded SuperPoint model
# Loaded SuperGlue model ("outdoor" weights)
# ==> Processing image directory input: /home/elea/Documents/HORAO/repositories/RIAP/temp/alignment/to_align/2025-06-05_T_CALF_FR_T0_S5_1__3c02f1ad-4c54-4ab7-ba40-b9a38aeea1f9/2025-06-05_T_CALF_FR_T1_S5_1
# ==> Will write outputs to /home/elea/Documents/HORAO/repositories/RIAP/temp/alignment/to_align/2025-06-05_T_CALF_FR_T0_S5_1__3c02f1ad-4c54-4ab7-ba40-b9a38aeea1f9/2025-06-05_T_CALF_FR_T1_S5_1
# Skipping visualization, will not show a GUI.
# ==> Keyboard control:
# 	n: select the current frame as the anchor
# 	e/r: increase/decrease the keypoint confidence threshold
# 	d/f: increase/decrease the match filtering threshold
# 	k: toggle the visualization of keypoints
# 	q: quit
# [Timer] data=0.003 forward=0.142 viz=0.005 total=0.150 sec {6.7 FPS}
# Writing image to /home/elea/Documents/HORAO/repositories/RIAP/temp/alignment/to_align/2025-06-05_T_CALF_FR_T0_S5_1__3c02f1ad-4c54-4ab7-ba40-b9a38aeea1f9/2025-06-05_T_CALF_FR_T1_S5_1/matches_000000_000001.png
# Finished demo_superglue.py
# Namespace(input='/home/elea/Documents/HORAO/repositories/RIAP/temp/alignment/to_align/2025-06-05_T_CALF_FR_T0_S5_1__3c02f1ad-4c54-4ab7-ba40-b9a38aeea1f9/2025-06-05_T_CALF_FR_T2_S5_1', output_dir='/home/elea/Documents/HORAO/repositories/RIAP/temp/alignment/to_align/2025-06-05_T_CALF_FR_T0_S5_1__3c02f1ad-4c54-4ab7-ba40-b9a38aeea1f9/2025-06-05_T_CALF_FR_T2_S5_1', image_glob=['*.png', '*.jpg', '*.jpeg'], skip=1, max_length=1000000, resize=[-1], superglue='outdoor', max_keypoints=-1, keypoint_threshold=0.005, nms_radius=4, sinkhorn_iterations=20, match_threshold=0.2, show_keypoints=False, no_display=True, force_cpu=False)
# Will not resize images
# Running inference on device "cuda"
# Loaded SuperPoint model
# Loaded SuperGlue model ("outdoor" weights)
# ==> Processing image directory input: /home/elea/Documents/HORAO/repositories/RIAP/temp/alignment/to_align/2025-06-05_T_CALF_FR_T0_S5_1__3c02f1ad-4c54-4ab7-ba40-b9a38aeea1f9/2025-06-05_T_CALF_FR_T2_S5_1
# ==> Will write outputs to /home/elea/Documents/HORAO/repositories/RIAP/temp/alignment/to_align/2025-06-05_T_CALF_FR_T0_S5_1__3c02f1ad-4c54-4ab7-ba40-b9a38aeea1f9/2025-06-05_T_CALF_FR_T2_S5_1
# Skipping visualization, will not show a GUI.
# ==> Keyboard control:
# 	n: select the current frame as the anchor
# 	e/r: increase/decrease the keypoint confidence threshold
# 	d/f: increase/decrease the match filtering threshold
# 	k: toggle the visualization of keypoints
# 	q: quit
# [Timer] data=0.003 forward=0.135 viz=0.004 total=0.143 sec {7.0 FPS}
# Writing image to /home/elea/Documents/HORAO/repositories/RIAP/temp/alignment/to_align/2025-06-05_T_CALF_FR_T0_S5_1__3c02f1ad-4c54-4ab7-ba40-b9a38aeea1f9/2025-06-05_T_CALF_FR_T2_S5_1/matches_000000_000001.png
# Finished demo_superglue.py
# Namespace(input='/home/elea/Documents/HORAO/repositories/RIAP/temp/alignment/to_align/2025-06-05_T_CALF_FR_T0_S5_1__3c02f1ad-4c54-4ab7-ba40-b9a38aeea1f9/2025-06-05_T_CALF_FR_T5_S5_1', output_dir='/home/elea/Documents/HORAO/repositories/RIAP/temp/alignment/to_align/2025-06-05_T_CALF_FR_T0_S5_1__3c02f1ad-4c54-4ab7-ba40-b9a38aeea1f9/2025-06-05_T_CALF_FR_T5_S5_1', image_glob=['*.png', '*.jpg', '*.jpeg'], skip=1, max_length=1000000, resize=[-1], superglue='outdoor', max_keypoints=-1, keypoint_threshold=0.005, nms_radius=4, sinkhorn_iterations=20, match_threshold=0.2, show_keypoints=False, no_display=True, force_cpu=False)
# Will not resize images
# Running inference on device "cuda"
# Loaded SuperPoint model
# Loaded SuperGlue model ("outdoor" weights)
# ==> Processing image directory input: /home/elea/Documents/HORAO/repositories/RIAP/temp/alignment/to_align/2025-06-05_T_CALF_FR_T0_S5_1__3c02f1ad-4c54-4ab7-ba40-b9a38aeea1f9/2025-06-05_T_CALF_FR_T5_S5_1
# ==> Will write outputs to /home/elea/Documents/HORAO/repositories/RIAP/temp/alignment/to_align/2025-06-05_T_CALF_FR_T0_S5_1__3c02f1ad-4c54-4ab7-ba40-b9a38aeea1f9/2025-06-05_T_CALF_FR_T5_S5_1
# Skipping visualization, will not show a GUI.
# ==> Keyboard control:
# 	n: select the current frame as the anchor
# 	e/r: increase/decrease the keypoint confidence threshold
# 	d/f: increase/decrease the match filtering threshold
# 	k: toggle the visualization of keypoints
# 	q: quit
# [Timer] data=0.003 forward=0.139 viz=0.004 total=0.146 sec {6.9 FPS}
# Writing image to /home/elea/Documents/HORAO/repositories/RIAP/temp/alignment/to_align/2025-06-05_T_CALF_FR_T0_S5_1__3c02f1ad-4c54-4ab7-ba40-b9a38aeea1f9/2025-06-05_T_CALF_FR_T5_S5_1/matches_000000_000001.png
# Finished demo_superglue.py
# Namespace(input='/home/elea/Documents/HORAO/repositories/RIAP/temp/alignment/to_align/2025-06-05_T_CALF_FR_T0_S5_1__3c02f1ad-4c54-4ab7-ba40-b9a38aeea1f9/2025-06-05_T_CALF_FR_T4_S5_1', output_dir='/home/elea/Documents/HORAO/repositories/RIAP/temp/alignment/to_align/2025-06-05_T_CALF_FR_T0_S5_1__3c02f1ad-4c54-4ab7-ba40-b9a38aeea1f9/2025-06-05_T_CALF_FR_T4_S5_1', image_glob=['*.png', '*.jpg', '*.jpeg'], skip=1, max_length=1000000, resize=[-1], superglue='outdoor', max_keypoints=-1, keypoint_threshold=0.005, nms_radius=4, sinkhorn_iterations=20, match_threshold=0.2, show_keypoints=False, no_display=True, force_cpu=False)
# Will not resize images
# Running inference on device "cuda"
# Loaded SuperPoint model
# Loaded SuperGlue model ("outdoor" weights)
# ==> Processing image directory input: /home/elea/Documents/HORAO/repositories/RIAP/temp/alignment/to_align/2025-06-05_T_CALF_FR_T0_S5_1__3c02f1ad-4c54-4ab7-ba40-b9a38aeea1f9/2025-06-05_T_CALF_FR_T4_S5_1
# ==> Will write outputs to /home/elea/Documents/HORAO/repositories/RIAP/temp/alignment/to_align/2025-06-05_T_CALF_FR_T0_S5_1__3c02f1ad-4c54-4ab7-ba40-b9a38aeea1f9/2025-06-05_T_CALF_FR_T4_S5_1
# Skipping visualization, will not show a GUI.
# ==> Keyboard control:
# 	n: select the current frame as the anchor
# 	e/r: increase/decrease the keypoint confidence threshold
# 	d/f: increase/decrease the match filtering threshold
# 	k: toggle the visualization of keypoints
# 	q: quit
# [Timer] data=0.003 forward=0.133 viz=0.004 total=0.140 sec {7.2 FPS}
# Writing image to /home/elea/Documents/HORAO/repositories/RIAP/temp/alignment/to_align/2025-06-05_T_CALF_FR_T0_S5_1__3c02f1ad-4c54-4ab7-ba40-b9a38aeea1f9/2025-06-05_T_CALF_FR_T4_S5_1/matches_000000_000001.png
# Finished demo_superglue.py
# 2026-02-12 00:46:24.914 | INFO     | riap.riap:process:254 - Alignment completed
# 2026-02-12 00:46:24.915 | SUCCESS  | riap.riap:process:260 - Folders aligned successfully
# 2026-02-12 00:46:24.915 | INFO     | riap.riap:process:262 - Step 3: Propagating ROIs and collecting statistics
# Processing ROIs: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 4/4 [00:02<00:00,  1.74it/s]
# 2026-02-12 00:46:27.879 | SUCCESS  | riap.riap:process:264 - Results saved in /home/elea/Documents/HORAO/repositories/RIAP/data/measurements/2025-06-05_T_CALF_FR_T0_S5_1/polarimetry/550nm/50x50_images

# %% [markdown]
# ### 3. Generates the output for plotting

# %%
riap_analyser.compare_parameters()
# Out:
# 2026-02-12 00:46:27.922 | INFO     | riap.riap:__export_results:548 - Exporting combined statistics to Excel files in /home/elea/Documents/HORAO/repositories/RIAP/output/IMPV1/superglue
