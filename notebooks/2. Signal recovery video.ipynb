# %%
# %load_ext autoreload
# %autoreload 2
from pathlib import Path
from riap.register import create_drying_video
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
data_path = Path('/media/elea/ssd/EDEMA/sec2-drying/')

text_mins = {
    "TW_15": "10 minutes",
    "TW_16": "20 minutes",
    "TW_17": "30 minutes",
    "TW_18": "40 minutes",
    "TW_19": "50 minutes",
    "TW_20": "60 minutes",
    "TW_21": "90 minutes",
    "TW_22": "120 minutes",
    "TW_23": "150 minutes",
    "TW_24": "210 minutes",
}

create_drying_video(data_path, data_path / "recovery.mp4", time_base="TW_0", text_mins=text_mins)
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 11/11 [00:00<00:00, 58.87it/s]
# ✅ MP4 saved to: /media/elea/ssd/EDEMA/sec2-drying/recovery.mp4
